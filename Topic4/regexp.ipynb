# %%
# Regular Expressions in Python

# import re. re is a built-in package in Python that you can use with regular expressions. 

# re.search() - returns a match object if there is a match anywhere in the string
# re.match() - returns a match object if the match is at the beginning of the string
# re.findall() - returns a list of all matches in the string
# re.split() - returns a list of the string split by the matches
# re.sub() - replaces the matches with a new string

# %%
import pandas as pd
# import re. not directly needed as we are using pandas. re is used in pandas.

# read the data from the csv file
data = pd.read_csv('people-100.csv')

# %%
data.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
# use split to get domains
# split the email address by the @ symbol and get the domain name
data['domain'] = data['Email'].str.split('@').str[1] # split the email address by the @ symbol and get the domain name
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %%
data.drop('domain', axis=1, inplace=True) # drop the domain column. 
data.head(3) # check if the column is dropped
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title
# 0  001-084-906-7849x73518    1945-10-26  Games developer
# 1       214.112.6044x4913    1910-03-24   Phytotherapist
# 2            277.609.7938    1992-07-02        Homeopath

# %%
# string.replace method can be used to replace a substring in a string. pandas documentation says that it is faster than using the re.sub() method.
# not to be confused with built in replace in python. -->gives error. see next code
string = 'ann has 1000 euro, john has 234 euro'
NewString = string.replace(r'\d', 'X', regex=True) # replace all digits with X in the string using regex
print(NewString)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 # string.replace method can be used to replace a substring in a string. pandas documentation says that it is faster than using the re.sub() method.
#       2 # not to be confused with built in replace in python. -->gives error. see next code
#       3 string = 'ann has 1000 euro, john has 234 euro'
# ----> 4 NewString = string.replace(r'\d', 'X', regex=True) # replace all digits with X in the string using regex
#       5 print(NewString)
#
# TypeError: str.replace() takes no keyword arguments

# %%
# find and replace reg exp in pandas. 

pattern = r'.*@' # pattern to match the email address. r is used to indicate that it is a raw string. 
data['domain'] = data['Email'].str.replace(pattern, '', regex=True) # replace the email address with an empty string
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %%
# a more precise way to replace all digits with X in the string using regex
pattern = r'.*@([\w\.]+\.\w{2,3})' # pattern to match the email address. r is used to indicate that it is a raw string.
data['domain'] = data['Email'].str.replace(pattern, r'\1', regex=True) # replace the email address with the domain name
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       domain
# 0  001-084-906-7849x73518    1945-10-26  Games developer  example.net
# 1       214.112.6044x4913    1910-03-24   Phytotherapist  example.com
# 2            277.609.7938    1992-07-02        Homeopath  example.com

# %% [markdown]
# #### The phone numbers
#
# They are a mess of different formats, some with hyphens others dots and some have extensions to clean these up lets:
# -   assume that they are all phone numbers
# -   put main numbers without any extensions or other characters into another column
# -   put the extensions into a separate column (numbers after the x)
#
# ##### The main numbers
#
# If there is an x we want the numbers before without any hyphens or dots. i am going to do this in a number of steps.

# %%
# x followed by any number of digits and replace it with blank in the phone number and put it into a new column..


the_extension_pattern = r'x\d*' # pattern to match the extension number. r is used to indicate that it is a raw string. 
data['clean_phone']=data['Phone'].str.replace(the_extension_pattern, '', regex=True) # replace the extension number with an empty string. 
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title       clean_phone
# 0  001-084-906-7849x73518    1945-10-26  Games developer  001-084-906-7849
# 1       214.112.6044x4913    1910-03-24   Phytotherapist      214.112.6044
# 2            277.609.7938    1992-07-02        Homeopath      277.609.7938

# %%
# get rid of hyphens, dots, round brackets, and spaces in the phone number and put it into a new column.

otherchars_pattern = r'[\-\. \(\)]*' # pattern to match the other characters. r is used to indicate that it is a raw string.
data['clean_phone'] = data['clean_phone'].str.replace(otherchars_pattern, '', regex=True) # replace the other characters with an empty string.
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title    clean_phone
# 0  001-084-906-7849x73518    1945-10-26  Games developer  0010849067849
# 1       214.112.6044x4913    1910-03-24   Phytotherapist    +1141126044
# 2            277.609.7938    1992-07-02        Homeopath    +1776097938

# %%
# some have extension. get rid of extension and put it into a new column.
# want to insert a +1 in front of 001 in the phone number.. find things that dont start with either a + or a 0 and replace it with +1

prefix_pattern=r'^([^\+0].*)' # pattern to match the prefix. r is used to indicate that it is a raw string.
data['clean_phone'] = data['clean_phone'].str.replace(prefix_pattern,'+1\\1', regex=True) # replace the prefix with +1
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title    clean_phone
# 0  001-084-906-7849x73518    1945-10-26  Games developer  0010849067849
# 1       214.112.6044x4913    1910-03-24   Phytotherapist    +1141126044
# 2            277.609.7938    1992-07-02        Homeopath    +1776097938

# %%
# replace the 00s with +1 in the phone number and put it into a new column.

prefix_pattern=r'^00(.*)' # pattern to match the prefix. r is used to indicate that it is a raw string.
data['clean_phone'] = data['clean_phone'].str.replace(prefix_pattern,'+1\\1', regex=True) # replace the prefix with +1  
data.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title    clean_phone
# 0  001-084-906-7849x73518    1945-10-26  Games developer  +110849067849
# 1       214.112.6044x4913    1910-03-24   Phytotherapist    +1141126044
# 2            277.609.7938    1992-07-02        Homeopath    +1776097938

# %%
# the extensions: 
# find neater way to extract the extensions and put it into a new column.

extension_pattern = r'x(\d+)' # pattern to match the extension number. r is used to indicate that it is a raw string.
data['extension'] = data['Phone'].str.extract(extension_pattern)
 # extract the extension number and put it into a new column.
data.head(3)

# references: 
#pandas.series.str.extract
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title    clean_phone  \
# 0  001-084-906-7849x73518    1945-10-26  Games developer  +110849067849
# 1       214.112.6044x4913    1910-03-24   Phytotherapist    +1141126044
# 2            277.609.7938    1992-07-02        Homeopath    +1776097938
#
#   extension
# 0     73518
# 1      4913
# 2       NaN

# %%
# filtering: you can filter rows in pandas based on a regular expression.eg find all the rows that have an international prefix in the phone number.

# find all the rows that have an international prefix in the phone number.(+)

international_prefix = r'^\+|00' # pattern to match the international prefix. r is used to indicate that it is a raw string.

data[data['Phone'].str.contains(international_prefix, regex=True)] # filter the rows that have an international prefix in the phone number.
# Out:
#     Index          User Id First Name   Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby     Terrell    Male
# 5       6  bfDD7CDEF5D865B       Erin         Day    Male
# 6       7  bE9EEf34cB72AF7  Katherine        Buck  Female
# 7       8  2EFC6A4e77FaEaC    Ricardo      Hinton    Male
# 9      10  8e4FB470FE19bF0     Isaiah       Downs    Male
# 14     15  1F0B7D65A00DAF9    Crystal      Farmer    Male
# 15     16  50Bb061cB30B461     Thomas      Knight  Female
# 19     20  88473e15D5c3cD0      Jared    Mitchell  Female
# 22     23  cBbBcA0FCA3C4Bc      Randy      Barnes    Male
# 23     24  f1f89173353aD90     Janice      Rhodes  Female
# 28     29  66F096D36Ebae11       Judy     Buckley    Male
# 29     30  F0fE2faAd78F8b5     Norman       Weber    Male
# 30     31  5d2feAfbdCAA6B5     Isaiah     Camacho  Female
# 32     33  8Ef7DBfcaB02b6B     Bonnie     Andrews  Female
# 33     34  6Dec5b5542F8ed8    Brandon     Schmidt  Female
# 36     37  aa614aAE4B7Cf0C    Leonard       Hurst    Male
# 37     38  ACcde95AAe3e6cC       Gene        Rich  Female
# 39     40  e92A191E345fA3A      Tanya    Mckinney  Female
# 41     42  CEFA7BBCef013AE       Kirk       Walsh  Female
# 47     48  Ee4eB129dC7913A      Becky       Brady    Male
# 49     50  E47FB71DD9ACCd9     Joshua     Sweeney    Male
# 52     53  9F5DeD7aD228F5a    Beverly     Esparza  Female
# 54     55  60FdBFd5e7BE8fF      Debra       Payne  Female
# 60     61  bB9e49E506F65ed      Shari   Daugherty    Male
# 61     62  Ed724605A403D91      Kelli      Garner    Male
# 62     63  0aBE5ACb18E0c10     Jackie     Bennett    Male
# 64     65  Ee6974f90eeCe18     Harold     Barnett  Female
# 65     66  cEf02C076afa07f      Larry      Harper    Male
# 69     70  e75e5DBfcb68887     Sandra          Wu    Male
# 70     71  6a53a8D41dDF6de       Ryan      Benton    Male
# 73     74  dBfA17Aaf16b4ab   Veronica      Briggs  Female
# 79     80  6e6a5b885F6496d   Terrence        Huff    Male
# 80     81  12DCb4ED8E01D5C      Tyler       Foley  Female
# 81     82  E1cB5cA8CA7CC0a     Andrew      Waters    Male
# 82     83  AedDfaE8Cf49F07   Reginald  Stephenson    Male
# 83     84  bff9853aFAeF772    Douglas       Reese  Female
# 84     85  E883773cA5219Be      Helen  Williamson  Female
# 86     87  5834700fbEd2771    Chelsea     Dickson    Male
# 87     88  2b0Ab1Dc9E01D7E     Dustin      Bailey    Male
# 88     89  3f3a3D89ad042Dd      Harry      Medina  Female
# 91     92  d6EA619A7C4aA95      Jamie       Hardy  Female
# 95     96  5eFda7caAeB260E     Dennis      Barnes  Female
# 96     97  CCbFce93d3720bE      Steve   Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley        Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer    Oconnell  Female
#
#                           Email                   Phone Date of birth  \
# 0          elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 5           tconner@example.org   001-171-649-9856x5553    2015-10-28
# 6       conniecowan@example.com   +1-773-151-6685x49162    1989-01-22
# 7       wyattbishop@example.com  001-447-699-7998x88612    1924-03-26
# 9   virginiaterrell@example.org    +1-511-372-1544x8206    1964-09-20
# 14         pmiranda@example.org         +1-024-377-5391    1992-03-09
# 15   braunpriscilla@example.net         +1-360-880-0766    2006-02-18
# 19          jcortez@example.com         +1-958-849-6781    1921-01-18
# 22        huangbill@example.org  001-960-629-7164x67214    1947-12-30
# 23  juarezdominique@example.net   001-249-314-9742x6996    1999-11-01
# 28         irosales@example.net  001-654-208-1241x52830    1963-07-28
# 29          mconrad@example.com            223.002.0429    1957-05-21
# 30         jimblake@example.org        001-536-544-3367    1966-04-07
# 32        caitlin24@example.net    +1-253-987-2776x9161    1953-12-21
# 33          mconley@example.net     +1-386-673-1465x006    1931-05-12
# 36        clinton78@example.org      941-038-0427x38800    1938-03-13
# 37       luisdeleon@example.org   +1-356-818-6604x89537    1946-08-22
# 39     vickihouston@example.com       (830)774-9002x086    2003-03-12
# 41    stephenfuller@example.org   001-826-496-5529x8661    2009-04-08
# 47      erikmueller@example.org           (390)002-0863    1957-06-27
# 49       daisymcgee@example.net        875.994.2100x535    1954-07-28
# 52          iphelps@example.net    +1-327-578-8754x6771    1930-12-09
# 54        yolanda07@example.org  001-731-525-8400x52593    1927-08-20
# 60        kalvarado@example.org   001-951-655-4798x6124    1944-11-24
# 61      jodyvincent@example.org       995.000.4213x0982    2010-01-17
# 62   hutchinsonkirk@example.com   001-740-937-0846x0087    1915-11-11
# 64         nathan65@example.org         +1-026-265-6392    1943-03-15
# 65          maria32@example.org    +1-244-630-3792x4121    2021-05-05
# 69           ubanks@example.com     +1-096-606-6454x067    1925-04-28
# 70      lopezdebbie@example.org     +1-695-557-9948x485    2020-10-06
# 73     weissbridget@example.com   +1-521-589-2387x48490    1974-06-08
# 79      cassandra80@example.org       221.800.6408x5416    1944-02-27
# 80      johnathan72@example.org   001-386-469-3075x8030    1908-09-19
# 81            nhall@example.net    +1-376-865-2765x3351    1948-05-14
# 82        erikaball@example.net     +1-832-500-6044x475    2010-02-08
# 83     nixonvanessa@example.net   001-834-660-8312x9864    1961-11-11
# 84         melvin08@example.net        001-377-726-4229    1911-08-11
# 86  johnnyhendricks@example.net  001-698-651-0138x18588    1958-05-13
# 87          pbarron@example.net     +1-965-621-1157x345    1908-08-22
# 88       olsenmalik@example.net         +1-451-099-5805    1947-08-24
# 91    sheenadouglas@example.com     (900)803-9295x11533    1994-07-17
# 95          bmartin@example.org    001-095-524-2112x257    1954-07-30
# 96        latasha46@example.net        001-865-478-5157    1932-04-29
# 97         regina11@example.org      995-542-3004x76800    1994-12-28
# 98   alexiscantrell@example.org    001-273-685-6932x092    2012-04-12
#
#                                Job Title    clean_phone extension
# 0                        Games developer  +110849067849     73518
# 5               Waste management officer  +111716499856      5553
# 6                   Intelligence analyst   +17731516685     49162
# 7                         Hydrogeologist  +114476997998     88612
# 9                         Engineer, site   +15113721544      8206
# 14               Agricultural consultant   +10243775391       NaN
# 15       Sport and exercise psychologist   +13608800766       NaN
# 19                      Paediatric nurse   +19588496781       NaN
# 22  Outdoor activities/education manager  +119606297164     67214
# 23                     Drilling engineer  +112493149742      6996
# 28                   Art gallery manager  +116542081241     52830
# 29                                Gaffer    +1230020429       NaN
# 30                     Food technologist  +115365443367       NaN
# 32                   Seismic interpreter   +12539872776      9161
# 33                  Engineer, biomedical   +13866731465       006
# 36      Accountant, chartered management    +1410380427     38800
# 37                    Surveyor, quantity   +13568186604     89537
# 39           Information systems manager    +1307749002       086
# 41                 Accounting technician  +118264965529      8661
# 47                   Seismic interpreter    +1900020863       NaN
# 49             Education officer, museum    +1759942100       535
# 52           Passenger transport manager   +13275788754      6771
# 54     Special educational needs teacher  +117315258400     52593
# 60                               Curator  +119516554798      6124
# 61                         Retail banker    +1950004213      0982
# 62                          Neurosurgeon  +117409370846      0087
# 64                  Biochemist, clinical   +10262656392       NaN
# 65              Scientist, water quality   +12446303792      4121
# 69                     Warehouse manager   +10966066454       067
# 70               Physiological scientist   +16955579948       485
# 73                   Structural engineer   +15215892387     48490
# 79           Careers information officer    +1218006408      5416
# 80                             Economist  +113864693075      8030
# 81                    Jewellery designer   +13768652765      3351
# 82            Contracting civil engineer   +18325006044       475
# 83             Higher education lecturer  +118346608312      9864
# 84           Lecturer, further education  +113777264229       NaN
# 86              Teacher, early years/pre  +116986510138     18588
# 87                 Travel agency manager   +19656211157       345
# 88              Technical sales engineer   +14510995805       NaN
# 91                Conservator, furniture    +1008039295     11533
# 95                     Software engineer  +110955242112       257
# 96                             Barrister  +118654785157       NaN
# 97                        Police officer    +1955423004     76800
# 98                  Broadcast journalist  +112736856932       092

# %%
data[data['Phone'].str.contains(r'^\+|00', regex=True)] # filter the rows that have an international prefix in the phone number.
# Out:
#     Index          User Id First Name   Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby     Terrell    Male
# 5       6  bfDD7CDEF5D865B       Erin         Day    Male
# 6       7  bE9EEf34cB72AF7  Katherine        Buck  Female
# 7       8  2EFC6A4e77FaEaC    Ricardo      Hinton    Male
# 9      10  8e4FB470FE19bF0     Isaiah       Downs    Male
# 14     15  1F0B7D65A00DAF9    Crystal      Farmer    Male
# 15     16  50Bb061cB30B461     Thomas      Knight  Female
# 19     20  88473e15D5c3cD0      Jared    Mitchell  Female
# 22     23  cBbBcA0FCA3C4Bc      Randy      Barnes    Male
# 23     24  f1f89173353aD90     Janice      Rhodes  Female
# 28     29  66F096D36Ebae11       Judy     Buckley    Male
# 29     30  F0fE2faAd78F8b5     Norman       Weber    Male
# 30     31  5d2feAfbdCAA6B5     Isaiah     Camacho  Female
# 32     33  8Ef7DBfcaB02b6B     Bonnie     Andrews  Female
# 33     34  6Dec5b5542F8ed8    Brandon     Schmidt  Female
# 36     37  aa614aAE4B7Cf0C    Leonard       Hurst    Male
# 37     38  ACcde95AAe3e6cC       Gene        Rich  Female
# 39     40  e92A191E345fA3A      Tanya    Mckinney  Female
# 41     42  CEFA7BBCef013AE       Kirk       Walsh  Female
# 47     48  Ee4eB129dC7913A      Becky       Brady    Male
# 49     50  E47FB71DD9ACCd9     Joshua     Sweeney    Male
# 52     53  9F5DeD7aD228F5a    Beverly     Esparza  Female
# 54     55  60FdBFd5e7BE8fF      Debra       Payne  Female
# 60     61  bB9e49E506F65ed      Shari   Daugherty    Male
# 61     62  Ed724605A403D91      Kelli      Garner    Male
# 62     63  0aBE5ACb18E0c10     Jackie     Bennett    Male
# 64     65  Ee6974f90eeCe18     Harold     Barnett  Female
# 65     66  cEf02C076afa07f      Larry      Harper    Male
# 69     70  e75e5DBfcb68887     Sandra          Wu    Male
# 70     71  6a53a8D41dDF6de       Ryan      Benton    Male
# 73     74  dBfA17Aaf16b4ab   Veronica      Briggs  Female
# 79     80  6e6a5b885F6496d   Terrence        Huff    Male
# 80     81  12DCb4ED8E01D5C      Tyler       Foley  Female
# 81     82  E1cB5cA8CA7CC0a     Andrew      Waters    Male
# 82     83  AedDfaE8Cf49F07   Reginald  Stephenson    Male
# 83     84  bff9853aFAeF772    Douglas       Reese  Female
# 84     85  E883773cA5219Be      Helen  Williamson  Female
# 86     87  5834700fbEd2771    Chelsea     Dickson    Male
# 87     88  2b0Ab1Dc9E01D7E     Dustin      Bailey    Male
# 88     89  3f3a3D89ad042Dd      Harry      Medina  Female
# 91     92  d6EA619A7C4aA95      Jamie       Hardy  Female
# 95     96  5eFda7caAeB260E     Dennis      Barnes  Female
# 96     97  CCbFce93d3720bE      Steve   Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley        Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer    Oconnell  Female
#
#                           Email                   Phone Date of birth  \
# 0          elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 5           tconner@example.org   001-171-649-9856x5553    2015-10-28
# 6       conniecowan@example.com   +1-773-151-6685x49162    1989-01-22
# 7       wyattbishop@example.com  001-447-699-7998x88612    1924-03-26
# 9   virginiaterrell@example.org    +1-511-372-1544x8206    1964-09-20
# 14         pmiranda@example.org         +1-024-377-5391    1992-03-09
# 15   braunpriscilla@example.net         +1-360-880-0766    2006-02-18
# 19          jcortez@example.com         +1-958-849-6781    1921-01-18
# 22        huangbill@example.org  001-960-629-7164x67214    1947-12-30
# 23  juarezdominique@example.net   001-249-314-9742x6996    1999-11-01
# 28         irosales@example.net  001-654-208-1241x52830    1963-07-28
# 29          mconrad@example.com            223.002.0429    1957-05-21
# 30         jimblake@example.org        001-536-544-3367    1966-04-07
# 32        caitlin24@example.net    +1-253-987-2776x9161    1953-12-21
# 33          mconley@example.net     +1-386-673-1465x006    1931-05-12
# 36        clinton78@example.org      941-038-0427x38800    1938-03-13
# 37       luisdeleon@example.org   +1-356-818-6604x89537    1946-08-22
# 39     vickihouston@example.com       (830)774-9002x086    2003-03-12
# 41    stephenfuller@example.org   001-826-496-5529x8661    2009-04-08
# 47      erikmueller@example.org           (390)002-0863    1957-06-27
# 49       daisymcgee@example.net        875.994.2100x535    1954-07-28
# 52          iphelps@example.net    +1-327-578-8754x6771    1930-12-09
# 54        yolanda07@example.org  001-731-525-8400x52593    1927-08-20
# 60        kalvarado@example.org   001-951-655-4798x6124    1944-11-24
# 61      jodyvincent@example.org       995.000.4213x0982    2010-01-17
# 62   hutchinsonkirk@example.com   001-740-937-0846x0087    1915-11-11
# 64         nathan65@example.org         +1-026-265-6392    1943-03-15
# 65          maria32@example.org    +1-244-630-3792x4121    2021-05-05
# 69           ubanks@example.com     +1-096-606-6454x067    1925-04-28
# 70      lopezdebbie@example.org     +1-695-557-9948x485    2020-10-06
# 73     weissbridget@example.com   +1-521-589-2387x48490    1974-06-08
# 79      cassandra80@example.org       221.800.6408x5416    1944-02-27
# 80      johnathan72@example.org   001-386-469-3075x8030    1908-09-19
# 81            nhall@example.net    +1-376-865-2765x3351    1948-05-14
# 82        erikaball@example.net     +1-832-500-6044x475    2010-02-08
# 83     nixonvanessa@example.net   001-834-660-8312x9864    1961-11-11
# 84         melvin08@example.net        001-377-726-4229    1911-08-11
# 86  johnnyhendricks@example.net  001-698-651-0138x18588    1958-05-13
# 87          pbarron@example.net     +1-965-621-1157x345    1908-08-22
# 88       olsenmalik@example.net         +1-451-099-5805    1947-08-24
# 91    sheenadouglas@example.com     (900)803-9295x11533    1994-07-17
# 95          bmartin@example.org    001-095-524-2112x257    1954-07-30
# 96        latasha46@example.net        001-865-478-5157    1932-04-29
# 97         regina11@example.org      995-542-3004x76800    1994-12-28
# 98   alexiscantrell@example.org    001-273-685-6932x092    2012-04-12
#
#                                Job Title    clean_phone extension
# 0                        Games developer  +110849067849     73518
# 5               Waste management officer  +111716499856      5553
# 6                   Intelligence analyst   +17731516685     49162
# 7                         Hydrogeologist  +114476997998     88612
# 9                         Engineer, site   +15113721544      8206
# 14               Agricultural consultant   +10243775391       NaN
# 15       Sport and exercise psychologist   +13608800766       NaN
# 19                      Paediatric nurse   +19588496781       NaN
# 22  Outdoor activities/education manager  +119606297164     67214
# 23                     Drilling engineer  +112493149742      6996
# 28                   Art gallery manager  +116542081241     52830
# 29                                Gaffer    +1230020429       NaN
# 30                     Food technologist  +115365443367       NaN
# 32                   Seismic interpreter   +12539872776      9161
# 33                  Engineer, biomedical   +13866731465       006
# 36      Accountant, chartered management    +1410380427     38800
# 37                    Surveyor, quantity   +13568186604     89537
# 39           Information systems manager    +1307749002       086
# 41                 Accounting technician  +118264965529      8661
# 47                   Seismic interpreter    +1900020863       NaN
# 49             Education officer, museum    +1759942100       535
# 52           Passenger transport manager   +13275788754      6771
# 54     Special educational needs teacher  +117315258400     52593
# 60                               Curator  +119516554798      6124
# 61                         Retail banker    +1950004213      0982
# 62                          Neurosurgeon  +117409370846      0087
# 64                  Biochemist, clinical   +10262656392       NaN
# 65              Scientist, water quality   +12446303792      4121
# 69                     Warehouse manager   +10966066454       067
# 70               Physiological scientist   +16955579948       485
# 73                   Structural engineer   +15215892387     48490
# 79           Careers information officer    +1218006408      5416
# 80                             Economist  +113864693075      8030
# 81                    Jewellery designer   +13768652765      3351
# 82            Contracting civil engineer   +18325006044       475
# 83             Higher education lecturer  +118346608312      9864
# 84           Lecturer, further education  +113777264229       NaN
# 86              Teacher, early years/pre  +116986510138     18588
# 87                 Travel agency manager   +19656211157       345
# 88              Technical sales engineer   +14510995805       NaN
# 91                Conservator, furniture    +1008039295     11533
# 95                     Software engineer  +110955242112       257
# 96                             Barrister  +118654785157       NaN
# 97                        Police officer    +1955423004     76800
# 98                  Broadcast journalist  +112736856932       092

# %%
# last one got all the numbers with 00. need it to just have numbers starting with 00.

data[data['Phone'].str.contains(r'\+|00')] # filter the rows that have an international prefix in the phone number.
# Out:
#     Index          User Id First Name   Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby     Terrell    Male
# 5       6  bfDD7CDEF5D865B       Erin         Day    Male
# 6       7  bE9EEf34cB72AF7  Katherine        Buck  Female
# 7       8  2EFC6A4e77FaEaC    Ricardo      Hinton    Male
# 9      10  8e4FB470FE19bF0     Isaiah       Downs    Male
# 14     15  1F0B7D65A00DAF9    Crystal      Farmer    Male
# 15     16  50Bb061cB30B461     Thomas      Knight  Female
# 19     20  88473e15D5c3cD0      Jared    Mitchell  Female
# 22     23  cBbBcA0FCA3C4Bc      Randy      Barnes    Male
# 23     24  f1f89173353aD90     Janice      Rhodes  Female
# 28     29  66F096D36Ebae11       Judy     Buckley    Male
# 29     30  F0fE2faAd78F8b5     Norman       Weber    Male
# 30     31  5d2feAfbdCAA6B5     Isaiah     Camacho  Female
# 32     33  8Ef7DBfcaB02b6B     Bonnie     Andrews  Female
# 33     34  6Dec5b5542F8ed8    Brandon     Schmidt  Female
# 36     37  aa614aAE4B7Cf0C    Leonard       Hurst    Male
# 37     38  ACcde95AAe3e6cC       Gene        Rich  Female
# 39     40  e92A191E345fA3A      Tanya    Mckinney  Female
# 41     42  CEFA7BBCef013AE       Kirk       Walsh  Female
# 47     48  Ee4eB129dC7913A      Becky       Brady    Male
# 49     50  E47FB71DD9ACCd9     Joshua     Sweeney    Male
# 52     53  9F5DeD7aD228F5a    Beverly     Esparza  Female
# 54     55  60FdBFd5e7BE8fF      Debra       Payne  Female
# 60     61  bB9e49E506F65ed      Shari   Daugherty    Male
# 61     62  Ed724605A403D91      Kelli      Garner    Male
# 62     63  0aBE5ACb18E0c10     Jackie     Bennett    Male
# 64     65  Ee6974f90eeCe18     Harold     Barnett  Female
# 65     66  cEf02C076afa07f      Larry      Harper    Male
# 69     70  e75e5DBfcb68887     Sandra          Wu    Male
# 70     71  6a53a8D41dDF6de       Ryan      Benton    Male
# 73     74  dBfA17Aaf16b4ab   Veronica      Briggs  Female
# 79     80  6e6a5b885F6496d   Terrence        Huff    Male
# 80     81  12DCb4ED8E01D5C      Tyler       Foley  Female
# 81     82  E1cB5cA8CA7CC0a     Andrew      Waters    Male
# 82     83  AedDfaE8Cf49F07   Reginald  Stephenson    Male
# 83     84  bff9853aFAeF772    Douglas       Reese  Female
# 84     85  E883773cA5219Be      Helen  Williamson  Female
# 86     87  5834700fbEd2771    Chelsea     Dickson    Male
# 87     88  2b0Ab1Dc9E01D7E     Dustin      Bailey    Male
# 88     89  3f3a3D89ad042Dd      Harry      Medina  Female
# 91     92  d6EA619A7C4aA95      Jamie       Hardy  Female
# 95     96  5eFda7caAeB260E     Dennis      Barnes  Female
# 96     97  CCbFce93d3720bE      Steve   Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley        Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer    Oconnell  Female
#
#                           Email                   Phone Date of birth  \
# 0          elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 5           tconner@example.org   001-171-649-9856x5553    2015-10-28
# 6       conniecowan@example.com   +1-773-151-6685x49162    1989-01-22
# 7       wyattbishop@example.com  001-447-699-7998x88612    1924-03-26
# 9   virginiaterrell@example.org    +1-511-372-1544x8206    1964-09-20
# 14         pmiranda@example.org         +1-024-377-5391    1992-03-09
# 15   braunpriscilla@example.net         +1-360-880-0766    2006-02-18
# 19          jcortez@example.com         +1-958-849-6781    1921-01-18
# 22        huangbill@example.org  001-960-629-7164x67214    1947-12-30
# 23  juarezdominique@example.net   001-249-314-9742x6996    1999-11-01
# 28         irosales@example.net  001-654-208-1241x52830    1963-07-28
# 29          mconrad@example.com            223.002.0429    1957-05-21
# 30         jimblake@example.org        001-536-544-3367    1966-04-07
# 32        caitlin24@example.net    +1-253-987-2776x9161    1953-12-21
# 33          mconley@example.net     +1-386-673-1465x006    1931-05-12
# 36        clinton78@example.org      941-038-0427x38800    1938-03-13
# 37       luisdeleon@example.org   +1-356-818-6604x89537    1946-08-22
# 39     vickihouston@example.com       (830)774-9002x086    2003-03-12
# 41    stephenfuller@example.org   001-826-496-5529x8661    2009-04-08
# 47      erikmueller@example.org           (390)002-0863    1957-06-27
# 49       daisymcgee@example.net        875.994.2100x535    1954-07-28
# 52          iphelps@example.net    +1-327-578-8754x6771    1930-12-09
# 54        yolanda07@example.org  001-731-525-8400x52593    1927-08-20
# 60        kalvarado@example.org   001-951-655-4798x6124    1944-11-24
# 61      jodyvincent@example.org       995.000.4213x0982    2010-01-17
# 62   hutchinsonkirk@example.com   001-740-937-0846x0087    1915-11-11
# 64         nathan65@example.org         +1-026-265-6392    1943-03-15
# 65          maria32@example.org    +1-244-630-3792x4121    2021-05-05
# 69           ubanks@example.com     +1-096-606-6454x067    1925-04-28
# 70      lopezdebbie@example.org     +1-695-557-9948x485    2020-10-06
# 73     weissbridget@example.com   +1-521-589-2387x48490    1974-06-08
# 79      cassandra80@example.org       221.800.6408x5416    1944-02-27
# 80      johnathan72@example.org   001-386-469-3075x8030    1908-09-19
# 81            nhall@example.net    +1-376-865-2765x3351    1948-05-14
# 82        erikaball@example.net     +1-832-500-6044x475    2010-02-08
# 83     nixonvanessa@example.net   001-834-660-8312x9864    1961-11-11
# 84         melvin08@example.net        001-377-726-4229    1911-08-11
# 86  johnnyhendricks@example.net  001-698-651-0138x18588    1958-05-13
# 87          pbarron@example.net     +1-965-621-1157x345    1908-08-22
# 88       olsenmalik@example.net         +1-451-099-5805    1947-08-24
# 91    sheenadouglas@example.com     (900)803-9295x11533    1994-07-17
# 95          bmartin@example.org    001-095-524-2112x257    1954-07-30
# 96        latasha46@example.net        001-865-478-5157    1932-04-29
# 97         regina11@example.org      995-542-3004x76800    1994-12-28
# 98   alexiscantrell@example.org    001-273-685-6932x092    2012-04-12
#
#                                Job Title    clean_phone extension
# 0                        Games developer  +110849067849     73518
# 5               Waste management officer  +111716499856      5553
# 6                   Intelligence analyst   +17731516685     49162
# 7                         Hydrogeologist  +114476997998     88612
# 9                         Engineer, site   +15113721544      8206
# 14               Agricultural consultant   +10243775391       NaN
# 15       Sport and exercise psychologist   +13608800766       NaN
# 19                      Paediatric nurse   +19588496781       NaN
# 22  Outdoor activities/education manager  +119606297164     67214
# 23                     Drilling engineer  +112493149742      6996
# 28                   Art gallery manager  +116542081241     52830
# 29                                Gaffer    +1230020429       NaN
# 30                     Food technologist  +115365443367       NaN
# 32                   Seismic interpreter   +12539872776      9161
# 33                  Engineer, biomedical   +13866731465       006
# 36      Accountant, chartered management    +1410380427     38800
# 37                    Surveyor, quantity   +13568186604     89537
# 39           Information systems manager    +1307749002       086
# 41                 Accounting technician  +118264965529      8661
# 47                   Seismic interpreter    +1900020863       NaN
# 49             Education officer, museum    +1759942100       535
# 52           Passenger transport manager   +13275788754      6771
# 54     Special educational needs teacher  +117315258400     52593
# 60                               Curator  +119516554798      6124
# 61                         Retail banker    +1950004213      0982
# 62                          Neurosurgeon  +117409370846      0087
# 64                  Biochemist, clinical   +10262656392       NaN
# 65              Scientist, water quality   +12446303792      4121
# 69                     Warehouse manager   +10966066454       067
# 70               Physiological scientist   +16955579948       485
# 73                   Structural engineer   +15215892387     48490
# 79           Careers information officer    +1218006408      5416
# 80                             Economist  +113864693075      8030
# 81                    Jewellery designer   +13768652765      3351
# 82            Contracting civil engineer   +18325006044       475
# 83             Higher education lecturer  +118346608312      9864
# 84           Lecturer, further education  +113777264229       NaN
# 86              Teacher, early years/pre  +116986510138     18588
# 87                 Travel agency manager   +19656211157       345
# 88              Technical sales engineer   +14510995805       NaN
# 91                Conservator, furniture    +1008039295     11533
# 95                     Software engineer  +110955242112       257
# 96                             Barrister  +118654785157       NaN
# 97                        Police officer    +1955423004     76800
# 98                  Broadcast journalist  +112736856932       092

# %%
# starts with a + or 00. 
# filtering out particular rows in a dataframe based on a regular expression in a particular column.
# prepping data for analysis.

# re very useful for data cleaning and data wrangling.
